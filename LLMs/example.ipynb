# %%
from engine import *

# %%
DEEPSEEK_KEY = "paste your key here"
OPENAI_KEY = "paste your key here"

# %% [markdown]
# Below is an example of a test for multiplication. For median and parity, you can run `one_median_test` and `one_parity_test` with similar arguments.

# %%
metrics, accuracy, cots = await one_multiplication_test(
    api_key=DEEPSEEK_KEY,
    max_char=4, # n digits
    n_tests=1, # number of runs
    n_max_tokens=None, # legacy argument
    random_seed=42,
    model="deepseek" # or "o1-mini"
)

print(f"Accuracy: {accuracy}")
print(metrics)

print("\n\n\n------------------------------\nReasoning trace example:")
print(cots[0])
# Out:
# 100%|██████████| 1/1 [01:01<00:00, 61.95s/it]
# Accuracy: 1.0
# [{'x': 7271, 'y': 861, 'prediction': 6260331, 'label': 6260331, 'n_tokens': 2132, 'correct': True}]
#
#
#
# ------------------------------
# Reasoning trace example:
# Okay, I need to multiply 7271 by 861 manually. Let me think about how to approach this step by step.
#
# First, I remember that multiplying large numbers manually involves breaking them down by each digit of the smaller number, multiplying each part by the larger number, and then adding up the results. Let me verify which number is smaller. 7271 is a four-digit number, and 861 is a three-digit number, so I'll use 861 as the multiplier.
#
# Breaking down 861 into its individual digits: 8 (hundreds place), 6 (tens place), and 1 (ones place). So I need to compute three separate products and then sum them up with appropriate shifts.
#
# ...
